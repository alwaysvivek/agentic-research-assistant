# %% [markdown]
# # Read pdfs

# %%
from pypdf import PdfReader

def extract_text_from_pdf(path) -> str:
    reader = PdfReader(path)

    all_text = ""

    for page in reader.pages:
        text = page.extract_text()
        if text:
            all_text += text + "\n"

    return all_text

def export_text_to_txt(text, export_path):
    with open(export_path, "w") as file:
        file.write(text)

# %%
from pathlib import Path 

data_path = Path("data")

list(data_path.glob("*.pdf"))
# Out:
# [PosixPath('data/Dwarf_Hotot.pdf'),
#  PosixPath('data/Holland_Lop.pdf'),
#  PosixPath('data/Netherland_Dwarf_rabbit.pdf'),
#  PosixPath('data/Dwarf_rabbit.pdf')]

# %%
for pdf_path in data_path.glob("*.pdf"):
    pdf_text = extract_text_from_pdf(pdf_path)

    filename = f"{pdf_path.stem.casefold()}.txt"

    export_text_to_txt(pdf_text, data_path / filename)

# %% [markdown]
# ## Explore knowledge base

# %%
import lancedb 
from backend.constants import VECTOR_DATABASE_PATH

db = lancedb.connect(VECTOR_DATABASE_PATH)
db.table_names()
# Out:
# ['articles']

# %%
db["articles"].to_pandas()
# Out:
#                     doc_id                                           filepath  \
# 0              holland_lop  /Users/aigineer/Documents/explorations/AI_engi...
# 1  netherland_dwarf_rabbit  /Users/aigineer/Documents/explorations/AI_engi...
# 2              dwarf_hotot  /Users/aigineer/Documents/explorations/AI_engi...
# 3             dwarf_rabbit  /Users/aigineer/Documents/explorations/AI_engi...
#
#                   filename                                            content  \
# 0              holland_lop  Holland Lop\nHolland lop standing on her back ...
# 1  netherland_dwarf_rabbit  Netherland Dwarf rabbit\nCountry of\norigin\n ...
# 2              dwarf_hotot  Dwarf Hotot\nCountry\nof origin\nFrance\nUse S...
# 3             dwarf_rabbit  A dwarf rabbit\n(Netherland Dwarf breed)\nBaby...
#
#                                            embedding
# 0  [-0.026729755, 0.012941162, 0.009253166, -0.05...
# 1  [-0.010614065, 0.004320113, 0.013331566, -0.05...
# 2  [-0.0360854, 0.011616136, 0.015652055, -0.0470...
# 3  [-0.015948843, -0.0020334467, 0.020679306, -0....

# %%
db["articles"].schema
# Out:
# doc_id: string not null
# filepath: string not null
# filename: string not null
# content: string not null
# embedding: fixed_size_list<item: float>[3072]
#   child 0, item: float
# -- schema metadata --
# embedding_functions: '[
#   {
#     "name": "gemini-text",
#     "model": {
#    ' + 111
